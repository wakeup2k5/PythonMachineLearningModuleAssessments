# %% [markdown]
# # Download the Dataset
#
# Download the image in the following link: https://robogarden.s3.us-west-2.amazonaws.com/content/mini-project/cat.png
#
# # Reading an image
#
# Read an image using matplotlib.
#
# Hint: You can use any alternative library for reading images. Check out OpenCV, skimage, etc.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("cat.png")

plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# # Re-organize
#
# Re-organize the pixels as a 2D array with dimensions (number of pixels, 3).
#
# In other words, a dataset with number of pixels samples and 3 columns.

# %%
reshaped_img = img.reshape(-1, 3)

print(reshaped_img[:5])

print(reshaped_img.shape)

# each subarray represents a pixel with RGB values
# Out:
# [[0.7372549  0.7882353  0.72156864]
#  [0.8666667  0.91764706 0.84705883]
#  [0.83137256 0.8862745  0.79607844]
#  [0.8156863  0.87058824 0.76862746]
#  [0.8117647  0.87058824 0.75686276]]
# (359170, 3)

# %%
from sklearn.cluster import KMeans

KMeansModel = KMeans(n_clusters= 10)
KMeansModel.fit(reshaped_img)

clustered_pixels = KMeansModel.cluster_centers_[KMeansModel.labels_]
clustered_image = clustered_pixels.reshape(img.shape)

plt.imshow(clustered_image)
plt.axis("off")
plt.show()

# %% [markdown]
# # Save the image
#
# Save the image as compressed.png.
#
# Is there a difference in the sizes of the two images?

# %%
plt.imsave("cat_compressed.png", clustered_image)

# %% [markdown]
# # Challenge Yourself (Optional)
#
# Try to Use Mean Shift or Hierarchical clustering algorithm instead of k-means. Does it work?

# %%
from sklearn.cluster import AgglomerativeClustering

AGGModel = AgglomerativeClustering(n_clusters = 10)
AGGModel.fit(reshaped_img)
# This wouln't work due to memory size?
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[68], line 14
#      12 # Step 3: Apply Agglomerative Clustering
#      13 agg_clustering = AgglomerativeClustering(n_clusters=10)  # Specify the number of clusters
# ---> 14 labels = agg_clustering.fit_predict(pixels)
#      16 # Step 4: Replace each pixel by the color of its cluster center
#      17 # Here we use the mean color of each cluster as the cluster's representative color
#      18 cluster_centers = np.array([pixels[labels == i].mean(axis=0) for i in range(10)])
#
# File c:\Users\jcollins\.conda\envs\wcs_python\Lib\site-packages\sklearn\cluster\_agglomerative.py:1129, in AgglomerativeClustering.fit_predict(self, X, y)
#    1108 def fit_predict(self, X, y=None):
#    1109     """Fit and return the result of each sample's clustering assignment.
#    1110
# ...
